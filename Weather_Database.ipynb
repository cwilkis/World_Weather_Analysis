# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitiude and longitude combinations
lats = np.random.uniform(low = -90, high = 90, size = 2000)
lngs = np.random.uniform(low = -180, high = 180, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitiude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 743

# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
# Import the requests library
import requests
# Import the API key
from config import weather_api_key

# %%
# Starting URL for weather map API call
url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=' + weather_api_key

# %%
# Import the time library 
import time

# %%
# Create an empty list to hold the weather data
city_data = []
# Print the beginning of the logging
print('Beginning Data Retrieval')
print('------------------------------')

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city
    city_url = url + '&q=' + city.replace(' ', '+')
    
    # Log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # Add 1 to the record count
    record_count += 1
    
# Run an API request for eachof the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        # Append the city information into city_data list
        city_data.append({'City': city.title(),
                         'Lat': city_lat,
                         'Lng': city_lng,
                         'Max Temp': city_max_temp,
                         'Humidity': city_humidity,
                         'Cloudiness': city_clouds,
                         'Wind Speed': city_wind,
                         'Country': city_country,
                         'Current Weather': city_description})
        
# If an error is experienced, skip the city
    except:
        print('City not found. Skipping...')
        pass
# Indicate that Data Loading is complete    
print('------------------------------')
print('Data Retrieval Complete       ')
print('------------------------------')
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1 | lebu
# Processing Record 2 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | kandava
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | padilla
# Processing Record 7 of Set 1 | georgetown
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | chuy
# Processing Record 11 of Set 1 | fort nelson
# Processing Record 12 of Set 1 | nikolskoye
# Processing Record 13 of Set 1 | takoradi
# Processing Record 14 of Set 1 | tinyahuarco
# Processing Record 15 of Set 1 | worland
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | vestmannaeyjar
# Processing Record 20 of Set 1 | qaanaaq
# Processing Record 21 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 1 | bud
# Processing Record 23 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 1 | east london
# Processing Record 25 of Set 1 | wajid
# Processing Record 26 of Set 1 | arraial do cabo
# Processing Record 27 of Set 1 | hithadhoo
# Processing Record 28 of Set 1 | hasaki
# Processing Record 29 of Set 1 | victoria
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | gamba
# Processing Record 32 of Set 1 | eganville
# Processing Record 33 of Set 1 | king city
# Processing Record 34 of Set 1 | new norfolk
# Processing Record 35 of Set 1 | tuktoyaktuk
# Processing Record 36 of Set 1 | veraval
# Processing Record 37 of Set 1 | el balyana
# City not found. Skipping...
# Processing Record 38 of Set 1 | yellowknife
# Processing Record 39 of Set 1 | sherlovaya gora
# Processing Record 40 of Set 1 | svetlogorsk
# Processing Record 41 of Set 1 | stornoway
# Processing Record 42 of Set 1 | alexandria
# Processing Record 43 of Set 1 | isangel
# Processing Record 44 of Set 1 | viedma
# Processing Record 45 of Set 1 | tual
# Processing Record 46 of Set 1 | santa maria
# Processing Record 47 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 1 | buala
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 50 of Set 1 | ilulissat
# Processing Record 1 of Set 2 | miri
# Processing Record 2 of Set 2 | adrar
# Processing Record 3 of Set 2 | mataura
# Processing Record 4 of Set 2 | esperance
# Processing Record 5 of Set 2 | codrington
# Processing Record 6 of Set 2 | verkh-usugli
# Processing Record 7 of Set 2 | sumbe
# Processing Record 8 of Set 2 | geraldton
# Processing Record 9 of Set 2 | port blair
# Processing Record 10 of Set 2 | lompoc
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | bambous virieux
# Processing Record 13 of Set 2 | vanderhoof
# Processing Record 14 of Set 2 | columbia
# Processing Record 15 of Set 2 | shush
# Processing Record 16 of Set 2 | muros
# Processing Record 17 of Set 2 | hobart
# Processing Record 18 of Set 2 | ust-tsilma
# Processing Record 19 of Set 2 | kodiak
# Processing Record 20 of Set 2 | mar del plata
# Processing Record 21 of Set 2 | narsaq
# Processing Record 22 of Set 2 | lima
# Processing Record 23 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 2 | kasempa
# Processing Record 25 of Set 2 | dunedin
# Processing Record 26 of Set 2 | olinda
# Processing Record 27 of Set 2 | sept-iles
# Processing Record 28 of Set 2 | port elizabeth
# Processing Record 29 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 2 | butaritari
# Processing Record 31 of Set 2 | hami
# Processing Record 32 of Set 2 | half moon bay
# Processing Record 33 of Set 2 | nanortalik
# Processing Record 34 of Set 2 | leningradskiy
# Processing Record 35 of Set 2 | palana
# Processing Record 36 of Set 2 | jamestown
# Processing Record 37 of Set 2 | louth
# Processing Record 38 of Set 2 | bajo baudo
# City not found. Skipping...
# Processing Record 39 of Set 2 | kolpashevo
# Processing Record 40 of Set 2 | raudeberg
# Processing Record 41 of Set 2 | stromness
# Processing Record 42 of Set 2 | dzialdowo
# Processing Record 43 of Set 2 | provideniya
# Processing Record 44 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 2 | chipinge
# Processing Record 46 of Set 2 | los llanos de aridane
# Processing Record 47 of Set 2 | torbay
# Processing Record 48 of Set 2 | atuona
# Processing Record 49 of Set 2 | santa cruz
# Processing Record 50 of Set 2 | te anau
# Processing Record 1 of Set 3 | batagay-alyta
# Processing Record 2 of Set 3 | husavik
# Processing Record 3 of Set 3 | longyearbyen
# Processing Record 4 of Set 3 | nome
# Processing Record 5 of Set 3 | ixtlahuacan del rio
# Processing Record 6 of Set 3 | dikson
# Processing Record 7 of Set 3 | uporovo
# Processing Record 8 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 3 | ouesso
# Processing Record 10 of Set 3 | lata
# Processing Record 11 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 3 | kavaratti
# Processing Record 13 of Set 3 | longlac
# City not found. Skipping...
# Processing Record 14 of Set 3 | uyuni
# Processing Record 15 of Set 3 | kendari
# Processing Record 16 of Set 3 | iqaluit
# Processing Record 17 of Set 3 | bucerias
# Processing Record 18 of Set 3 | anadyr
# Processing Record 19 of Set 3 | souillac
# Processing Record 20 of Set 3 | bethel
# Processing Record 21 of Set 3 | zhuhai
# Processing Record 22 of Set 3 | ituni
# City not found. Skipping...
# Processing Record 23 of Set 3 | shimoda
# Processing Record 24 of Set 3 | itaueira
# Processing Record 25 of Set 3 | besancon
# Processing Record 26 of Set 3 | pontianak
# Processing Record 27 of Set 3 | avarua
# Processing Record 28 of Set 3 | krasnoselkup
# Processing Record 29 of Set 3 | bredasdorp
# Processing Record 30 of Set 3 | margate
# Processing Record 31 of Set 3 | deputatskiy
# Processing Record 32 of Set 3 | hibbing
# Processing Record 33 of Set 3 | mentok
# City not found. Skipping...
# Processing Record 34 of Set 3 | tasiilaq
# Processing Record 35 of Set 3 | segovia
# Processing Record 36 of Set 3 | koson
# Processing Record 37 of Set 3 | richmond
# Processing Record 38 of Set 3 | richards bay
# Processing Record 39 of Set 3 | kaohsiung
# Processing Record 40 of Set 3 | mayo
# Processing Record 41 of Set 3 | castro
# Processing Record 42 of Set 3 | padang
# Processing Record 43 of Set 3 | constitucion
# Processing Record 44 of Set 3 | tura
# Processing Record 45 of Set 3 | kavieng
# Processing Record 46 of Set 3 | ponta do sol
# Processing Record 47 of Set 3 | liwale
# Processing Record 48 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 3 | rocha
# Processing Record 50 of Set 3 | xingyi
# Processing Record 1 of Set 4 | limuru
# Processing Record 2 of Set 4 | talcahuano
# Processing Record 3 of Set 4 | scarborough
# Processing Record 4 of Set 4 | la brea
# Processing Record 5 of Set 4 | yabrud
# Processing Record 6 of Set 4 | severo-kurilsk
# Processing Record 7 of Set 4 | mercedes
# Processing Record 8 of Set 4 | sao filipe
# Processing Record 9 of Set 4 | kiri buru
# Processing Record 10 of Set 4 | atar
# Processing Record 11 of Set 4 | meadow lake
# Processing Record 12 of Set 4 | ialibu
# Processing Record 13 of Set 4 | cowansville
# Processing Record 14 of Set 4 | tairua
# Processing Record 15 of Set 4 | vila
# Processing Record 16 of Set 4 | sarmanovo
# Processing Record 17 of Set 4 | okitipupa
# Processing Record 18 of Set 4 | skibbereen
# Processing Record 19 of Set 4 | port alfred
# Processing Record 20 of Set 4 | vila velha
# Processing Record 21 of Set 4 | tilichiki
# Processing Record 22 of Set 4 | saint-philippe
# Processing Record 23 of Set 4 | denpasar
# Processing Record 24 of Set 4 | barrow
# Processing Record 25 of Set 4 | okhotsk
# Processing Record 26 of Set 4 | san quintin
# Processing Record 27 of Set 4 | itabera
# Processing Record 28 of Set 4 | hermanus
# Processing Record 29 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 4 | guiberoua
# Processing Record 31 of Set 4 | roma
# Processing Record 32 of Set 4 | touros
# Processing Record 33 of Set 4 | coihaique
# Processing Record 34 of Set 4 | teya
# Processing Record 35 of Set 4 | rio grande
# Processing Record 36 of Set 4 | suicheng
# Processing Record 37 of Set 4 | cidreira
# Processing Record 38 of Set 4 | vardo
# Processing Record 39 of Set 4 | mocuba
# Processing Record 40 of Set 4 | ahipara
# Processing Record 41 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 42 of Set 4 | kyela
# Processing Record 43 of Set 4 | tynda
# Processing Record 44 of Set 4 | ishigaki
# Processing Record 45 of Set 4 | mahebourg
# Processing Record 46 of Set 4 | stoyba
# City not found. Skipping...
# Processing Record 47 of Set 4 | puerto narino
# Processing Record 48 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 49 of Set 4 | meulaboh
# Processing Record 50 of Set 4 | la ronge
# Processing Record 1 of Set 5 | carnarvon
# Processing Record 2 of Set 5 | namatanai
# Processing Record 3 of Set 5 | kisangani
# Processing Record 4 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 5 | laguna
# Processing Record 6 of Set 5 | bluff
# Processing Record 7 of Set 5 | avera
# Processing Record 8 of Set 5 | lagoa
# Processing Record 9 of Set 5 | maniitsoq
# Processing Record 10 of Set 5 | krasnoturansk
# Processing Record 11 of Set 5 | yulara
# Processing Record 12 of Set 5 | severnyy
# Processing Record 13 of Set 5 | lujan
# Processing Record 14 of Set 5 | lanzhou
# Processing Record 15 of Set 5 | bengkulu
# Processing Record 16 of Set 5 | high level
# Processing Record 17 of Set 5 | bell ville
# Processing Record 18 of Set 5 | luhyny
# Processing Record 19 of Set 5 | puerto colombia
# Processing Record 20 of Set 5 | khatanga
# Processing Record 21 of Set 5 | cabo san lucas
# Processing Record 22 of Set 5 | huilong
# Processing Record 23 of Set 5 | urucara
# Processing Record 24 of Set 5 | naze
# Processing Record 25 of Set 5 | paamiut
# Processing Record 26 of Set 5 | marystown
# Processing Record 27 of Set 5 | berlevag
# Processing Record 28 of Set 5 | ukiah
# Processing Record 29 of Set 5 | coquimbo
# Processing Record 30 of Set 5 | puerto ayora
# Processing Record 31 of Set 5 | kutum
# Processing Record 32 of Set 5 | victoria point
# Processing Record 33 of Set 5 | awbari
# Processing Record 34 of Set 5 | tuatapere
# Processing Record 35 of Set 5 | akyab
# Processing Record 36 of Set 5 | ribeira grande
# Processing Record 37 of Set 5 | lorengau
# Processing Record 38 of Set 5 | shingu
# Processing Record 39 of Set 5 | guatire
# Processing Record 40 of Set 5 | paranaiba
# Processing Record 41 of Set 5 | christchurch
# Processing Record 42 of Set 5 | asau
# Processing Record 43 of Set 5 | apastovo
# Processing Record 44 of Set 5 | sorland
# Processing Record 45 of Set 5 | luanda
# Processing Record 46 of Set 5 | pevek
# Processing Record 47 of Set 5 | yanchukan
# City not found. Skipping...
# Processing Record 48 of Set 5 | hofn
# Processing Record 49 of Set 5 | kieta
# Processing Record 50 of Set 5 | zhangye
# Processing Record 1 of Set 6 | pavlovka
# Processing Record 2 of Set 6 | inuvik
# Processing Record 3 of Set 6 | sorong
# Processing Record 4 of Set 6 | zaton
# Processing Record 5 of Set 6 | cardoso
# Processing Record 6 of Set 6 | saint-pierre
# Processing Record 7 of Set 6 | makakilo city
# Processing Record 8 of Set 6 | saint george
# Processing Record 9 of Set 6 | ust-nera
# Processing Record 10 of Set 6 | yushu
# Processing Record 11 of Set 6 | bairiki
# Processing Record 12 of Set 6 | wellington
# Processing Record 13 of Set 6 | snezhnogorsk
# Processing Record 14 of Set 6 | forbes
# Processing Record 15 of Set 6 | hervey bay
# Processing Record 16 of Set 6 | tayu
# Processing Record 17 of Set 6 | emerald
# Processing Record 18 of Set 6 | hong gai
# Processing Record 19 of Set 6 | marsa matruh
# Processing Record 20 of Set 6 | drochtersen
# Processing Record 21 of Set 6 | umea
# Processing Record 22 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 23 of Set 6 | bombay
# Processing Record 24 of Set 6 | otjiwarongo
# Processing Record 25 of Set 6 | portobelo
# Processing Record 26 of Set 6 | oksfjord
# Processing Record 27 of Set 6 | ahuimanu
# Processing Record 28 of Set 6 | vila franca do campo
# Processing Record 29 of Set 6 | tahta
# Processing Record 30 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 6 | upernavik
# Processing Record 32 of Set 6 | fairbanks
# Processing Record 33 of Set 6 | chokurdakh
# Processing Record 34 of Set 6 | sumbal
# Processing Record 35 of Set 6 | tutoia
# Processing Record 36 of Set 6 | changji
# Processing Record 37 of Set 6 | anshun
# Processing Record 38 of Set 6 | atambua
# Processing Record 39 of Set 6 | lazaro cardenas
# Processing Record 40 of Set 6 | poum
# Processing Record 41 of Set 6 | chulman
# Processing Record 42 of Set 6 | hoima
# Processing Record 43 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 44 of Set 6 | coruripe
# Processing Record 45 of Set 6 | tahe
# Processing Record 46 of Set 6 | chumphon
# Processing Record 47 of Set 6 | kendal
# Processing Record 48 of Set 6 | kruisfontein
# Processing Record 49 of Set 6 | egvekinot
# Processing Record 50 of Set 6 | mahibadhoo
# Processing Record 1 of Set 7 | ponta delgada
# Processing Record 2 of Set 7 | myre
# Processing Record 3 of Set 7 | caravelas
# Processing Record 4 of Set 7 | letka
# Processing Record 5 of Set 7 | carballo
# Processing Record 6 of Set 7 | aksha
# Processing Record 7 of Set 7 | antofagasta
# Processing Record 8 of Set 7 | hazaribag
# Processing Record 9 of Set 7 | boa vista
# Processing Record 10 of Set 7 | najran
# Processing Record 11 of Set 7 | pedasi
# Processing Record 12 of Set 7 | namibe
# Processing Record 13 of Set 7 | san onofre
# Processing Record 14 of Set 7 | pisco
# Processing Record 15 of Set 7 | luderitz
# Processing Record 16 of Set 7 | broome
# Processing Record 17 of Set 7 | hamilton
# Processing Record 18 of Set 7 | taltal
# Processing Record 19 of Set 7 | wana
# Processing Record 20 of Set 7 | kushmurun
# Processing Record 21 of Set 7 | vanavara
# Processing Record 22 of Set 7 | khandyga
# Processing Record 23 of Set 7 | yatou
# Processing Record 24 of Set 7 | kiama
# Processing Record 25 of Set 7 | brae
# Processing Record 26 of Set 7 | san cristobal
# Processing Record 27 of Set 7 | chikoy
# City not found. Skipping...
# Processing Record 28 of Set 7 | fortuna
# Processing Record 29 of Set 7 | seoul
# Processing Record 30 of Set 7 | lasa
# Processing Record 31 of Set 7 | nuevo progreso
# Processing Record 32 of Set 7 | grand gaube
# Processing Record 33 of Set 7 | sabang
# Processing Record 34 of Set 7 | dennery
# Processing Record 35 of Set 7 | komsomolskiy
# Processing Record 36 of Set 7 | igrim
# Processing Record 37 of Set 7 | ulundi
# Processing Record 38 of Set 7 | panjakent
# Processing Record 39 of Set 7 | faanui
# Processing Record 40 of Set 7 | horsham
# Processing Record 41 of Set 7 | pacific grove
# Processing Record 42 of Set 7 | ovsyanka
# Processing Record 43 of Set 7 | sitka
# Processing Record 44 of Set 7 | thompson
# Processing Record 45 of Set 7 | salym
# Processing Record 46 of Set 7 | miandrivazo
# Processing Record 47 of Set 7 | pryozerne
# Processing Record 48 of Set 7 | tessalit
# Processing Record 49 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 7 | thinadhoo
# Processing Record 1 of Set 8 | assiniboia
# Processing Record 2 of Set 8 | kahului
# Processing Record 3 of Set 8 | juneau
# Processing Record 4 of Set 8 | aswan
# Processing Record 5 of Set 8 | dharchula
# Processing Record 6 of Set 8 | kiunga
# Processing Record 7 of Set 8 | kamakwie
# Processing Record 8 of Set 8 | nazca
# Processing Record 9 of Set 8 | acapulco
# Processing Record 10 of Set 8 | villamontes
# Processing Record 11 of Set 8 | huarmey
# Processing Record 12 of Set 8 | cherskiy
# Processing Record 13 of Set 8 | nhulunbuy
# Processing Record 14 of Set 8 | lapithos
# Processing Record 15 of Set 8 | leo
# Processing Record 16 of Set 8 | tungor
# Processing Record 17 of Set 8 | nalut
# Processing Record 18 of Set 8 | kaitangata
# Processing Record 19 of Set 8 | ambon
# Processing Record 20 of Set 8 | sosnovo
# Processing Record 21 of Set 8 | zastron
# Processing Record 22 of Set 8 | dzilam gonzalez
# Processing Record 23 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 24 of Set 8 | bako
# Processing Record 25 of Set 8 | batouri
# Processing Record 26 of Set 8 | aksu
# Processing Record 27 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 28 of Set 8 | castrillon
# Processing Record 29 of Set 8 | kandalaksha
# Processing Record 30 of Set 8 | korem
# Processing Record 31 of Set 8 | abidjan
# Processing Record 32 of Set 8 | pareora
# Processing Record 33 of Set 8 | sosua
# Processing Record 34 of Set 8 | san pedro
# Processing Record 35 of Set 8 | pombas
# Processing Record 36 of Set 8 | klaksvik
# Processing Record 37 of Set 8 | toungoo
# City not found. Skipping...
# Processing Record 38 of Set 8 | anito
# Processing Record 39 of Set 8 | warrensburg
# Processing Record 40 of Set 8 | lubango
# Processing Record 41 of Set 8 | zyryanka
# Processing Record 42 of Set 8 | guerrero negro
# Processing Record 43 of Set 8 | corrales
# Processing Record 44 of Set 8 | ibb
# Processing Record 45 of Set 8 | bubaque
# Processing Record 46 of Set 8 | port macquarie
# Processing Record 47 of Set 8 | taoudenni
# Processing Record 48 of Set 8 | gisors
# Processing Record 49 of Set 8 | eyl
# Processing Record 50 of Set 8 | agadez
# Processing Record 1 of Set 9 | qurayyat
# Processing Record 2 of Set 9 | sola
# Processing Record 3 of Set 9 | rosetta
# Processing Record 4 of Set 9 | new amsterdam
# Processing Record 5 of Set 9 | gao
# Processing Record 6 of Set 9 | palmer
# Processing Record 7 of Set 9 | sur
# Processing Record 8 of Set 9 | przhevalskoye
# Processing Record 9 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 10 of Set 9 | keratea
# Processing Record 11 of Set 9 | sekoma
# Processing Record 12 of Set 9 | saskylakh
# Processing Record 13 of Set 9 | adolfo lopez mateos
# Processing Record 14 of Set 9 | laon
# Processing Record 15 of Set 9 | coyula
# Processing Record 16 of Set 9 | poya
# Processing Record 17 of Set 9 | saint-joseph
# Processing Record 18 of Set 9 | kapoeta
# Processing Record 19 of Set 9 | albury
# Processing Record 20 of Set 9 | tatsinskaya
# City not found. Skipping...
# Processing Record 21 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 22 of Set 9 | hay river
# Processing Record 23 of Set 9 | muzhi
# Processing Record 24 of Set 9 | youhao
# Processing Record 25 of Set 9 | gemena
# Processing Record 26 of Set 9 | lahad datu
# Processing Record 27 of Set 9 | korla
# Processing Record 28 of Set 9 | groningen
# Processing Record 29 of Set 9 | upata
# Processing Record 30 of Set 9 | cap malheureux
# Processing Record 31 of Set 9 | lavrentiya
# Processing Record 32 of Set 9 | airai
# Processing Record 33 of Set 9 | greeley
# Processing Record 34 of Set 9 | marsh harbour
# Processing Record 35 of Set 9 | dicabisagan
# Processing Record 36 of Set 9 | saint-louis
# Processing Record 37 of Set 9 | woodward
# Processing Record 38 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 39 of Set 9 | sinjar
# Processing Record 40 of Set 9 | milkovo
# Processing Record 41 of Set 9 | farafangana
# Processing Record 42 of Set 9 | kasongo
# Processing Record 43 of Set 9 | bihariganj
# Processing Record 44 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 9 | pandan
# Processing Record 46 of Set 9 | srednekolymsk
# Processing Record 47 of Set 9 | dubbo
# Processing Record 48 of Set 9 | bonavista
# Processing Record 49 of Set 9 | nizwa
# Processing Record 50 of Set 9 | tiksi
# Processing Record 1 of Set 10 | deming
# Processing Record 2 of Set 10 | jalu
# Processing Record 3 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 4 of Set 10 | kilindoni
# Processing Record 5 of Set 10 | doha
# Processing Record 6 of Set 10 | champerico
# Processing Record 7 of Set 10 | banmo
# City not found. Skipping...
# Processing Record 8 of Set 10 | hambantota
# Processing Record 9 of Set 10 | santona
# Processing Record 10 of Set 10 | tolland
# Processing Record 11 of Set 10 | oktyabrskiy
# Processing Record 12 of Set 10 | mnogovershinnyy
# Processing Record 13 of Set 10 | kenmare
# Processing Record 14 of Set 10 | kanallakion
# City not found. Skipping...
# Processing Record 15 of Set 10 | ponnani
# Processing Record 16 of Set 10 | saint-francois
# Processing Record 17 of Set 10 | sungaipenuh
# Processing Record 18 of Set 10 | wanaka
# Processing Record 19 of Set 10 | warmbad
# Processing Record 20 of Set 10 | lincoln
# Processing Record 21 of Set 10 | itarema
# Processing Record 22 of Set 10 | college
# Processing Record 23 of Set 10 | letterkenny
# Processing Record 24 of Set 10 | comodoro rivadavia
# Processing Record 25 of Set 10 | pangnirtung
# Processing Record 26 of Set 10 | japaratuba
# Processing Record 27 of Set 10 | ambulu
# Processing Record 28 of Set 10 | bograd
# Processing Record 29 of Set 10 | tyukalinsk
# Processing Record 30 of Set 10 | miles city
# Processing Record 31 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 32 of Set 10 | botwood
# Processing Record 33 of Set 10 | clyde river
# Processing Record 34 of Set 10 | narsingi
# Processing Record 35 of Set 10 | asayita
# City not found. Skipping...
# Processing Record 36 of Set 10 | nyurba
# Processing Record 37 of Set 10 | tommot
# Processing Record 38 of Set 10 | ust-kuyga
# Processing Record 39 of Set 10 | basco
# Processing Record 40 of Set 10 | gizo
# Processing Record 41 of Set 10 | yar-sale
# Processing Record 42 of Set 10 | levelland
# Processing Record 43 of Set 10 | nantucket
# Processing Record 44 of Set 10 | buariki
# City not found. Skipping...
# Processing Record 45 of Set 10 | ambilobe
# Processing Record 46 of Set 10 | katsuura
# Processing Record 47 of Set 10 | devils lake
# Processing Record 48 of Set 10 | punta alta
# Processing Record 49 of Set 10 | rauma
# Processing Record 50 of Set 10 | itaituba
# Processing Record 1 of Set 11 | shenjiamen
# Processing Record 2 of Set 11 | zaragoza
# Processing Record 3 of Set 11 | san patricio
# Processing Record 4 of Set 11 | maarianhamina
# Processing Record 5 of Set 11 | saint anthony
# Processing Record 6 of Set 11 | norman wells
# Processing Record 7 of Set 11 | biskamzha
# Processing Record 8 of Set 11 | bamenda
# Processing Record 9 of Set 11 | kumluca
# Processing Record 10 of Set 11 | puerto escondido
# Processing Record 11 of Set 11 | verkhnevilyuysk
# Processing Record 12 of Set 11 | alofi
# Processing Record 13 of Set 11 | zarand
# Processing Record 14 of Set 11 | pervomaysk
# Processing Record 15 of Set 11 | thessalon
# Processing Record 16 of Set 11 | ekhabi
# Processing Record 17 of Set 11 | bilibino
# Processing Record 18 of Set 11 | pangai
# Processing Record 19 of Set 11 | port hardy
# Processing Record 20 of Set 11 | sandakan
# Processing Record 21 of Set 11 | hermiston
# Processing Record 22 of Set 11 | barcelos
# Processing Record 23 of Set 11 | burla
# Processing Record 24 of Set 11 | topeka
# Processing Record 25 of Set 11 | dolores
# Processing Record 26 of Set 11 | the valley
# Processing Record 27 of Set 11 | olga
# Processing Record 28 of Set 11 | morant bay
# Processing Record 29 of Set 11 | karawang
# Processing Record 30 of Set 11 | maragogi
# Processing Record 31 of Set 11 | salgueiro
# Processing Record 32 of Set 11 | mizdah
# Processing Record 33 of Set 11 | presidencia roque saenz pena
# Processing Record 34 of Set 11 | zhezkazgan
# Processing Record 35 of Set 11 | lakes entrance
# Processing Record 36 of Set 11 | mogadishu
# Processing Record 37 of Set 11 | kupang
# Processing Record 38 of Set 11 | alcantara
# Processing Record 39 of Set 11 | khovu-aksy
# Processing Record 40 of Set 11 | bac lieu
# Processing Record 41 of Set 11 | chemin grenier
# Processing Record 42 of Set 11 | rawson
# Processing Record 43 of Set 11 | vallenar
# Processing Record 44 of Set 11 | salalah
# Processing Record 45 of Set 11 | shimanovsk
# Processing Record 46 of Set 11 | onega
# Processing Record 47 of Set 11 | potosi
# Processing Record 48 of Set 11 | rostovka
# Processing Record 49 of Set 11 | bathsheba
# Processing Record 50 of Set 11 | macara
# Processing Record 1 of Set 12 | martinsburg
# Processing Record 2 of Set 12 | ancud
# Processing Record 3 of Set 12 | roald
# Processing Record 4 of Set 12 | lasem
# Processing Record 5 of Set 12 | arrecife
# Processing Record 6 of Set 12 | aitape
# Processing Record 7 of Set 12 | jiwani
# Processing Record 8 of Set 12 | molokovo
# Processing Record 9 of Set 12 | lethem
# Processing Record 10 of Set 12 | puerto quijarro
# Processing Record 11 of Set 12 | gravdal
# Processing Record 12 of Set 12 | belyy yar
# Processing Record 13 of Set 12 | biu
# Processing Record 14 of Set 12 | beloha
# Processing Record 15 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 16 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 12 | sayyan
# Processing Record 18 of Set 12 | aykhal
# Processing Record 19 of Set 12 | hualmay
# Processing Record 20 of Set 12 | bangkalan
# Processing Record 21 of Set 12 | christiana
# Processing Record 22 of Set 12 | fairview
# Processing Record 23 of Set 12 | canon city
# Processing Record 24 of Set 12 | karratha
# Processing Record 25 of Set 12 | talnakh
# Processing Record 26 of Set 12 | kunda
# Processing Record 27 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 28 of Set 12 | natitingou
# Processing Record 29 of Set 12 | hare bay
# Processing Record 30 of Set 12 | vaitape
# Processing Record 31 of Set 12 | channarayapatna
# Processing Record 32 of Set 12 | aklavik
# Processing Record 33 of Set 12 | gulshat
# City not found. Skipping...
# Processing Record 34 of Set 12 | honghu
# Processing Record 35 of Set 12 | ereymentau
# Processing Record 36 of Set 12 | andenes
# Processing Record 37 of Set 12 | ulaangom
# Processing Record 38 of Set 12 | wuxue
# Processing Record 39 of Set 12 | okha
# Processing Record 40 of Set 12 | ambovombe
# Processing Record 41 of Set 12 | anloga
# Processing Record 42 of Set 12 | loiza
# Processing Record 43 of Set 12 | cairns
# Processing Record 44 of Set 12 | fethiye
# Processing Record 45 of Set 12 | cueramaro
# Processing Record 46 of Set 12 | douentza
# Processing Record 47 of Set 12 | dingle
# Processing Record 48 of Set 12 | jumla
# Processing Record 49 of Set 12 | yenagoa
# Processing Record 50 of Set 12 | luang prabang
# Processing Record 1 of Set 13 | hammerfest
# Processing Record 2 of Set 13 | san antero
# Processing Record 3 of Set 13 | thanyaburi
# Processing Record 4 of Set 13 | harper
# Processing Record 5 of Set 13 | loubomo
# Processing Record 6 of Set 13 | libreville
# Processing Record 7 of Set 13 | iwanai
# Processing Record 8 of Set 13 | bereda
# Processing Record 9 of Set 13 | waghai
# Processing Record 10 of Set 13 | abrau-dyurso
# Processing Record 11 of Set 13 | araceli
# Processing Record 12 of Set 13 | dong xoai
# Processing Record 13 of Set 13 | cayenne
# Processing Record 14 of Set 13 | chernyshevskiy
# Processing Record 15 of Set 13 | saint-jovite
# Processing Record 16 of Set 13 | sokoni
# Processing Record 17 of Set 13 | yumen
# Processing Record 18 of Set 13 | torata
# Processing Record 19 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 20 of Set 13 | kamaishi
# Processing Record 21 of Set 13 | bamnet narong
# Processing Record 22 of Set 13 | vao
# Processing Record 23 of Set 13 | benghazi
# Processing Record 24 of Set 13 | goundam
# Processing Record 25 of Set 13 | fare
# Processing Record 26 of Set 13 | marawi
# Processing Record 27 of Set 13 | mizan teferi
# Processing Record 28 of Set 13 | sinnamary
# Processing Record 29 of Set 13 | port hedland
# Processing Record 30 of Set 13 | kelvington
# Processing Record 31 of Set 13 | santa cruz de tenerife
# Processing Record 32 of Set 13 | ler
# Processing Record 33 of Set 13 | batticaloa
# Processing Record 34 of Set 13 | kamir
# Processing Record 35 of Set 13 | xiongyue
# Processing Record 36 of Set 13 | corinth
# Processing Record 37 of Set 13 | usinsk
# Processing Record 38 of Set 13 | sunndalsora
# Processing Record 39 of Set 13 | mingshui
# Processing Record 40 of Set 13 | katherine
# Processing Record 41 of Set 13 | sao joao da barra
# Processing Record 42 of Set 13 | riaba
# City not found. Skipping...
# Processing Record 43 of Set 13 | jadu
# Processing Record 44 of Set 13 | mehran
# Processing Record 45 of Set 13 | borogontsy
# Processing Record 46 of Set 13 | bayir
# Processing Record 47 of Set 13 | traverse city
# Processing Record 48 of Set 13 | oyama
# Processing Record 49 of Set 13 | rajauri
# Processing Record 50 of Set 13 | ketchikan
# Processing Record 1 of Set 14 | hovd
# Processing Record 2 of Set 14 | budogoshch
# Processing Record 3 of Set 14 | forestville
# Processing Record 4 of Set 14 | blairgowrie
# Processing Record 5 of Set 14 | praia da vitoria
# Processing Record 6 of Set 14 | maceio
# Processing Record 7 of Set 14 | palu
# Processing Record 8 of Set 14 | naustdal
# Processing Record 9 of Set 14 | kasamwa
# Processing Record 10 of Set 14 | oktyabrskoye
# Processing Record 11 of Set 14 | mount gambier
# Processing Record 12 of Set 14 | massena
# Processing Record 13 of Set 14 | gladstone
# Processing Record 14 of Set 14 | grindavik
# Processing Record 15 of Set 14 | kawana waters
# City not found. Skipping...
# Processing Record 16 of Set 14 | ginir
# Processing Record 17 of Set 14 | pierre
# Processing Record 18 of Set 14 | beyneu
# Processing Record 19 of Set 14 | den helder
# Processing Record 20 of Set 14 | crato
# Processing Record 21 of Set 14 | bela
# Processing Record 22 of Set 14 | grand island
# Processing Record 23 of Set 14 | sumenep
# Processing Record 24 of Set 14 | ostrovnoy
# Processing Record 25 of Set 14 | puerto carreno
# Processing Record 26 of Set 14 | puerto montt
# Processing Record 27 of Set 14 | mount isa
# Processing Record 28 of Set 14 | valparaiso
# Processing Record 29 of Set 14 | kangaba
# Processing Record 30 of Set 14 | teluk nibung
# Processing Record 31 of Set 14 | port elgin
# Processing Record 32 of Set 14 | portland
# Processing Record 33 of Set 14 | ha tinh
# Processing Record 34 of Set 14 | tabriz
# Processing Record 35 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 36 of Set 14 | ucluelet
# Processing Record 37 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 14 | priiskovyy
# Processing Record 39 of Set 14 | kaeo
# Processing Record 40 of Set 14 | sao felix do xingu
# Processing Record 41 of Set 14 | brandon
# Processing Record 42 of Set 14 | tupik
# Processing Record 43 of Set 14 | port lincoln
# Processing Record 44 of Set 14 | san rafael
# Processing Record 45 of Set 14 | sambava
# Processing Record 46 of Set 14 | tuy hoa
# Processing Record 47 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 48 of Set 14 | bowling green
# Processing Record 49 of Set 14 | awjilah
# Processing Record 50 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 1 of Set 15 | malangwa
# Processing Record 2 of Set 15 | kurkino
# Processing Record 3 of Set 15 | arkadak
# Processing Record 4 of Set 15 | jak
# Processing Record 5 of Set 15 | lahaina
# Processing Record 6 of Set 15 | along
# Processing Record 7 of Set 15 | sibolga
# Processing Record 8 of Set 15 | independencia
# Processing Record 9 of Set 15 | ternate
# Processing Record 10 of Set 15 | semey
# Processing Record 11 of Set 15 | humboldt
# Processing Record 12 of Set 15 | talaya
# Processing Record 13 of Set 15 | salta
# Processing Record 14 of Set 15 | ormara
# Processing Record 15 of Set 15 | darhan
# Processing Record 16 of Set 15 | quelimane
# Processing Record 17 of Set 15 | odweyne
# Processing Record 18 of Set 15 | chicama
# Processing Record 19 of Set 15 | salinas
# Processing Record 20 of Set 15 | wawa
# Processing Record 21 of Set 15 | progreso
# Processing Record 22 of Set 15 | olafsvik
# Processing Record 23 of Set 15 | xinmin
# Processing Record 24 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 15 | iberia
# Processing Record 26 of Set 15 | oxford
# Processing Record 27 of Set 15 | lithakia
# Processing Record 28 of Set 15 | shelburne
# Processing Record 29 of Set 15 | mumbwa
# Processing Record 30 of Set 15 | kalmunai
# Processing Record 31 of Set 15 | toftir
# City not found. Skipping...
# Processing Record 32 of Set 15 | atasu
# Processing Record 33 of Set 15 | guymon
# Processing Record 34 of Set 15 | auki
# Processing Record 35 of Set 15 | linjiang
# Processing Record 36 of Set 15 | tautira
# Processing Record 37 of Set 15 | bacuit
# City not found. Skipping...
# Processing Record 38 of Set 15 | port-gentil
# Processing Record 39 of Set 15 | bull savanna
# Processing Record 40 of Set 15 | humberto de campos
# Processing Record 41 of Set 15 | quatre cocos
# Processing Record 42 of Set 15 | misawa
# Processing Record 43 of Set 15 | panguna
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
len(city_data)
# Out:
# 688

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                  Lebu -37.6167  -73.6500     54.46        96         100
# 1             Cape Town -33.9258   18.4232     62.11        88          75
# 2               Kandava  57.0409   22.7747     42.76        85           5
# 3                  Hilo  19.7297 -155.0900     87.28        77         100
# 4               Padilla   3.2204  -76.3139     81.97        90          69
# ..                  ...      ...       ...       ...       ...         ...
# 683        Bull Savanna  17.8868  -77.5902     77.61        76          25
# 684  Humberto De Campos  -2.5983  -43.4611     75.92        93          43
# 685        Quatre Cocos -20.2078   57.7625     77.11        72         100
# 686              Misawa  40.6836  141.3597     57.60        83         100
# 687             Panguna  -6.3164  155.4848     80.10        65          59
#
#      Wind Speed Country   Current Weather
# 0          1.14      CL   overcast clouds
# 1         11.50      ZA     broken clouds
# 2          4.85      LV         clear sky
# 3          9.22      US   overcast clouds
# 4          2.13      CO     broken clouds
# ..          ...     ...               ...
# 683        0.98      JM  scattered clouds
# 684        4.34      BR  scattered clouds
# 685       12.15      MU   overcast clouds
# 686        4.07      JP   overcast clouds
# 687        2.68      PG     broken clouds
#
# [688 rows x 9 columns]

# %%
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Weather']
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Lebu      CL -37.6167  -73.6500     54.46        96         100
# 1  Cape Town      ZA -33.9258   18.4232     62.11        88          75
# 2    Kandava      LV  57.0409   22.7747     42.76        85           5
# 3       Hilo      US  19.7297 -155.0900     87.28        77         100
# 4    Padilla      CO   3.2204  -76.3139     81.97        90          69
#
#    Wind Speed  Current Weather
# 0        1.14  overcast clouds
# 1       11.50    broken clouds
# 2        4.85        clear sky
# 3        9.22  overcast clouds
# 4        2.13    broken clouds

# %%
# Create the output file (CSV)
output_data_file = "/Users/claud/Class/allhw/World_Weather_Analysis/Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
